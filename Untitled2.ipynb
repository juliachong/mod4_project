# %%
import pandas as pd

# %%
df = pd.read_csv('2017_dem.csv')
df
# Out:
#          GEO.id GEO.id2     GEO.display-label POPGROUP.id  \
# 0            Id     Id2             Geography          Id
# 1   0400000US01      01               Alabama         001
# 2   0400000US02      02                Alaska         001
# 3   0400000US04      04               Arizona         001
# 4   0400000US05      05              Arkansas         001
# 5   0400000US06      06            California         001
# 6   0400000US08      08              Colorado         001
# 7   0400000US09      09           Connecticut         001
# 8   0400000US10      10              Delaware         001
# 9   0400000US11      11  District of Columbia         001
# 10  0400000US12      12               Florida         001
# 11  0400000US13      13               Georgia         001
# 12  0400000US15      15                Hawaii         001
# 13  0400000US16      16                 Idaho         001
# 14  0400000US17      17              Illinois         001
# ...

# %%
df.columns = df.iloc[0]

# %%
df = df[1:]

# %%
df
# Out:
# 0            Id Id2             Geography   Id  Population Group  \
# 1   0400000US01  01               Alabama  001  Total population
# 2   0400000US02  02                Alaska  001  Total population
# 3   0400000US04  04               Arizona  001  Total population
# 4   0400000US05  05              Arkansas  001  Total population
# 5   0400000US06  06            California  001  Total population
# 6   0400000US08  08              Colorado  001  Total population
# 7   0400000US09  09           Connecticut  001  Total population
# 8   0400000US10  10              Delaware  001  Total population
# 9   0400000US11  11  District of Columbia  001  Total population
# 10  0400000US12  12               Florida  001  Total population
# 11  0400000US13  13               Georgia  001  Total population
# 12  0400000US15  15                Hawaii  001  Total population
# 13  0400000US16  16                 Idaho  001  Total population
# ...

# %%
df.drop(['Id', 'Id2', 'Id', 'Population Group'], axis=1, inplace=True)

# %%
df = df.T

# %%
monster_data.index
# Out:
# RangeIndex(start=1, stop=52, step=1)

# %%
df_cols = [col for col in df.index if 'Median family income' in col]
print(df_cols)
# Out:
# ['Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)', 'Margin of Error; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)', 'Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars) - Married-couple family', 'Margin of Error; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars) - Married-couple family']

# %%
df = df.T

# %%
df_colz = ['Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)']

# %%
df = df.T

# %%
income_2017 = df[['Geography', 'Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)']]

# %%
income_2017 = income_2017.rename(columns={"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)": "Median Income"})

# %%
income_2017 = income_2017.rename(columns={"Geography": "State"})

# %%
income_2017['Year'] = 2017
income_2017
# Out:
# 0                  State Median Income  Year
# 1                Alabama         61512  2017
# 2                 Alaska         86831  2017
# 3                Arizona         67886  2017
# 4               Arkansas         57421  2017
# 5             California         82009  2017
# 6               Colorado         84918  2017
# 7            Connecticut         93870  2017
# 8               Delaware         77082  2017
# 9   District of Columbia        106528  2017
# 10               Florida         64003  2017
# 11               Georgia         67983  2017
# 12                Hawaii         91460  2017
# 13                 Idaho         64178  2017
# 14              Illinois         79168  2017
# 15               Indiana         68085  2017
# 16                  Iowa         75076  2017
# 17                Kansas         72057  2017
# 18              Kentucky         61593  2017
# 19             Louisiana         60510  2017
# 20                 Maine         72177  2017
# ...

# %%
state = monster_data['Geography']

# %%
df['State'] = state
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
income_2016 = df[['State', 'Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-993c0666de47> in <module>
# ----> 1 income_2016 = df[['State', 'Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)']]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
income_2016 = income_2017.rename(columns={"Estimate; INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Families - Median family income (dollars)": "Median Income"})

# %%
income_2016['Year'] = 2016

# %%
df_16_17 = income_2016.merge(income_2017, how='left', on=['State'])

# %%
df_16_17.to_csv('Median Income 2016-2017')

# %%
voter_percent = pd.read_csv('hate_crimes.csv')

# %%
voter_percent = voter_percent[['state', 'share_voters_voted_trump']]

# %%
voter_percent.to_csv('Voter Percentage')

# %%
voter_percent = voter_percent.rename(columns={'state': 'State'})
# Out:
#                    State  share_voters_voted_trump
# 0                Alabama                      0.63
# 1                 Alaska                      0.53
# 2                Arizona                      0.50
# 3               Arkansas                      0.60
# 4             California                      0.33
# 5               Colorado                      0.44
# 6            Connecticut                      0.41
# 7               Delaware                      0.42
# 8   District of Columbia                      0.04
# 9                Florida                      0.49
# 10               Georgia                      0.51
# 11                Hawaii                      0.30
# 12                 Idaho                      0.59
# 13              Illinois                      0.39
# 14               Indiana                      0.57
# 15                  Iowa                      0.52
# 16                Kansas                      0.57
# ...

# %%
hate_17 = pd.read_csv('hate_crime_2017.csv')
vote_haters = voter_percent.merge(hate_17, how='left', on=['State'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-de9407827d29> in <module>
#       1 hate_17 = pd.read_csv('hate_crime_2017.csv')
# ----> 2 vote_haters = voter_percent.merge(hate_17, how='left', on=['State'])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
# ...

# %%
hate_17
# Out:
#                                       Table 12  \
# 0   Agency Hate Crime Reporting by State, 2017
# 1                          Participating state
# 2                                        Total
# 3                                      Alabama
# 4                                       Alaska
# 5                                      Arizona
# 6                                     Arkansas
# 7                                   California
# 8                                     Colorado
# 9                                  Connecticut
# 10                                    Delaware
# 11                        District of Columbia
# 12                                     Florida
# 13                                     Georgia
# 14                                       Idaho
# 15                                    Illinois
# 16                                     Indiana
# 17                                        Iowa
# 18                                      Kansas
# ...
