# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('2017_dem.csv')

# %%
df.columns = df.iloc[0]

# %%
df = df.drop([df.index[0]])

# %%
column_names = []
for i in df.columns:
    column_names.append(i)

# %%
df.columns.str.startswith('Margin')
df = df.loc[:,~df.columns.str.startswith('Margin')]

# %%
df
# Out:
# 0            Id Id2             Geography   Id  Population Group  \
# 1   0400000US01  01               Alabama  001  Total population
# 2   0400000US02  02                Alaska  001  Total population
# 3   0400000US04  04               Arizona  001  Total population
# 4   0400000US05  05              Arkansas  001  Total population
# 5   0400000US06  06            California  001  Total population
# 6   0400000US08  08              Colorado  001  Total population
# 7   0400000US09  09           Connecticut  001  Total population
# 8   0400000US10  10              Delaware  001  Total population
# 9   0400000US11  11  District of Columbia  001  Total population
# 10  0400000US12  12               Florida  001  Total population
# 11  0400000US13  13               Georgia  001  Total population
# 12  0400000US15  15                Hawaii  001  Total population
# 13  0400000US16  16                 Idaho  001  Total population
# ...

# %%
column_names
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Id',
#  'Population Group',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population',
#  'Margin of Error; TOTAL NUMBER OF RACES REPORTED - Total population',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - One race',
#  'Margin of Error; TOTAL NUMBER OF RACES REPORTED - Total population - One race',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Two races',
#  'Margin of Error; TOTAL NUMBER OF RACES REPORTED - Total population - Two races',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Three races',
#  'Margin of Error; TOTAL NUMBER OF RACES REPORTED - Total population - Three races',
#  'Estimate; TOTAL NUMBER OF RACES REPORTED - Total population - Four or more races',
#  'Margin of Error; TOTAL NUMBER OF RACES REPORTED - Total population - Four or more races',
#  'Estimate; SEX AND AGE - Total population',
#  'Margin of Error; SEX AND AGE - Total population',
# ...

# %%
df = df[['Geography', 'Estimate; PLACE OF BIRTH, CITIZENSHIP STATUS AND YEAR OF ENTRY - Foreign born','Estimate; SEX AND AGE - 65 years and over', 'Estimate; LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH - Population 5 years and over - English only']]

# %%
df.columns = ['state', 'foreigners', 'old', 'english']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-9006d1b47338> in <module>
# ----> 1 df.columns = ['state', 'foreigners', 'old', 'english']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ...

# %%
df.drop(['old'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-f37c0963342f> in <module>
# ----> 1 df.drop(['old'], axis=1, inplace=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
hate_crimes = pd.read_csv('hate_crime_2017.csv')

# %%
hate_crimes = hate_crimes.iloc[3:]

# %%
hate_crimes = hate_crimes[['Table 12', 'Unnamed: 2']]

# %%
hate_crimes.columns = ['state', 'crime']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

crime = hate_crimes['crime']
foreigners = np.log(df['foreigners'])
old = np.log(df['old'])
english = np.log(df['english'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'foreigners'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-f700738d46bd> in <module>
#       8
#       9 crime = hate_crimes['crime']
# ...

# %%
df = df.drop(df.index[11])
